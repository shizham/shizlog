# %% [markdown]
# <a href="https://colab.research.google.com/github/shizham/shizlog/blob/master/_notebooks/2022_04_30_My_First_PostG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is first page via colabo
# Generated by Jupyter
#
# $$
# \int
# $$

# %%
# comment 
1+1
# Out:
# 2

# %%
#hide
1+1
# Out:
# 2
